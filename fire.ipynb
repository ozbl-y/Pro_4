# %% [markdown]
# <a href="https://colab.research.google.com/github/ozbl-y/Triangle/blob/main/fire.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# !pip install ultralytics==8.0.20

# !pip install torch --upgrade
# !pip install ultralytics --upgrade

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.7/112.6 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="AS88LkHy9UiMpiljFd5v")
project = rf.workspace("young-hv4zv").project("fire_classification-vfilj")
version = project.version(4)
dataset = version.download("yolov8")

print(dataset.location)
# Out:
# mkdir: cannot create directory ‘/content/datasets’: File exists
# /content/datasets
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# /content/datasets/fire_classification-4

# %%
# %cd {HOME}

# !ls {dataset.location}

import os
print(dataset.location)
print(os.listdir(dataset.location))

# !yolo task=detect mode=train model=yolov8s.pt  data={dataset.location}/data.yaml epochs=100 imgsz=800 plots=True
# Out:
# /content
# data.yaml  README.dataset.txt  README.roboflow.txt  test  train  valid
# /content/datasets/fire_classification-4
# ['README.dataset.txt', 'README.roboflow.txt', 'test', 'train', 'data.yaml', 'valid']
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.15 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from google.colab import files

# 'best.pt' 파일 다운로드
files.download('/content/runs/detect/train13/weights/best.pt')
